# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!

# %%
import matplotlib.pyplot as plt
X = [0,1,2]
Y = [3,4,5]
plt.plot(X,Y)
